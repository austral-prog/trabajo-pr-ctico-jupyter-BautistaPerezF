# %% [markdown]
# # Assignment
#
# The assignment will require you to complete cells, create new ones, and move around some cells. You need to familiarize yourself with the Jupyter notebook interface. You can find a tutorial [here](https://www.dataquest.io/blog/jupyter-notebook-tutorial/).
#
#
# **MAKE SURE TO MAKE A COPY OF THIS ASSIGNMENT IN YOUR OWN REPOSITORY.** (delete this line in your new copy :) )

# %% [markdown]
# Bautista Perez Fernandez | Ingenieria Informatica | bperezfernandez@mail.austral.edu.ar
#
#
# ![SM-casinoonline-280920.webp](data:image/webp;base64,...)
# ## En esta imagen podemos apreciar la famosa ruleta que esta ubicada en uno de mis lugares favoritos que es el casino

# %% [markdown]
# ---

# %% [markdown]
# # [EXERCICE 5]

# %%
a= 3
b= 7

# %% [markdown]
# # resta

# %%
a - b
# Out:
# -4

# %% [markdown]
# # suma

# %%
a + b
# Out:
# 10

# %% [markdown]
# # multiplicacion

# %%
a * b
# Out:
# 21

# %%
# divicion
a / b
# Out:
# 0.42857142857142855
